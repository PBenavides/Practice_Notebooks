# %%
import quandl
import pandas as pd
quandl.ApiConfig.api_key = "yvFBQPr3jqiWypuisRMs"

# %%
stocks = ['TSLA','KO','AMZN','SCCO','BAP']
data = quandl.get_table('WIKI/PRICES', ticker = stocks,
                        qopts = { 'columns': ['date', 'ticker', 'adj_close'] },
                        date = { 'gte': '2016-1-1', 'lte': '2020-04-30' }, paginate=True)

# %%
stocks_2 = ['NVDA','BLK','TGT','CAT','GDX']
data_2 = quandl.get_table('WIKI/PRICES', ticker=stocks_2, 
                         qopts = { 'columns': ['date', 'ticker', 'adj_close'] },
                        date = { 'gte': '2016-1-1', 'lte': '2020-04-30' }, paginate=True)

# %%
df = pd.concat([data,data_2]).set_index('date')

# %%
df = df.pivot(columns='ticker')
df.columns = [col[1] for col in df.columns]

# %% [markdown]
# ### Calculating the Sharpe Ratio for our portfolio

# %%
#We will create a function to calculate the sharpe ratio.
def calculate_returns_sharpe_ratio(df,weights,total_investment=10000):
    sharpe_data = pd.DataFrame()
    for weight,stock in zip(weights,df.columns):
        norm_returns = df[stock]/df[stock].iloc[0]
        position = norm_returns*weight*total_investment
        sharpe_data = sharpe_data.append({stock:position},ignore_index=True)
    return sharpe_data

# %%
weights = [.35,.25,.2,.2]
s = calculate_returns_sharpe_ratio(df,weights)

# %%
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
table.pct_change()
# Out:
#                 AMZN        KO      SCCO      TSLA
# date
# 2016-01-04       NaN       NaN       NaN       NaN
# 2016-01-05 -0.005024  0.003538  0.011302  0.000090
# 2016-01-06 -0.001799 -0.005405 -0.028902 -0.019648
# 2016-01-07 -0.039058 -0.016541 -0.025397 -0.015477
# 2016-01-08 -0.001464 -0.002643 -0.019951 -0.021563
# ...              ...       ...       ...       ...
# 2018-03-21 -0.002931 -0.003707  0.013244  0.019256
# 2018-03-22 -0.023871 -0.005581 -0.027574 -0.023473
# 2018-03-23 -0.031436 -0.010056 -0.015651 -0.024458
# 2018-03-26  0.040319  0.008505  0.010288  0.008755
# 2018-03-27 -0.037799  0.004685 -0.011665 -0.082188
#
# [561 rows x 4 columns]

# %%
table.to_excel('data.xlsx')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(14,7))
for c in table.columns.values:
    plt.plot(table.index, table[c], lw=3, alpha=0.8, label=c)
plt.legend(loc='upper left', fontsize=12)
plt.ylabel('price in $')
# Out:
# C:\Users\pablo\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'price in $')
